# %% [markdown]
# ## **TALLER 1 PROCESAMIENTO DE DATOS A GRAN ESCALA**
#
#
# **Fecha**: 14/08/2026
#
# **Autor**: *juan david murcia lopez*
#
# **ID**: 00020552313
#
# **Tema**: Introducción a listas con cuaderno Python
#
# **Objetivo**:  Introducción al uso y funcionamiento de listas en el lenguaje "Python"
#
# **Descripción**: Este cuaderno estará centrado en desarrollar varios ejercicios sobre el uso de cadenas en Python, esto para aprender el uso de las funciones básicas de manipulación de cadenas.

# %% [markdown]
# <h2>Introducción</h2>
# En Python, una lista es una estructura de datos que permite almacenar una colección ordenada de elementos. Las listas se utilizan para organizar y manejar conjuntos de datos de forma flexible, ya que pueden contener distintos tipos de información y adaptarse a las necesidades del programa durante su ejecución.

# %% [markdown]
# Crea una lista <code>a_lit</code> con los siguientes elementos <code>1</code>, <code>hello</code>, <code>[1,2,3]</code> y <code>True</code>.

# %%
a_list = [1, "hello", [1,2,3], True]   #se crea una lista que contiene un entero, una cadena, otra lista y un booleano

# %% [markdown]
# Encuentra el valor almacenado en el índice 1 de <code>a_list</code>.

# %%
print(a_list[1])   #se imprime el elemento en la posición 1 de la lista, que es "hello"
# Out:
# hello

# %% [markdown]
# Obtén el elemento almacenado en el índice 1, 2 y 3 de <code>a_list</code>.

# %%
print(a_list[1:4])      #se hace Slicing para imprimir los indices indicados
# Out:
# ['hello', [1, 2, 3], True]

# %% [markdown]
# Concatena las siguientes listas <code>A = [1, 'a']</code> y <code>B = [2, 1, 'd']</code>:

# %%
A = [1, 'a']        #lista A
B = [2, 1, 'd']     #lista B
print(A+B)          #se concatenan las listas A y B y se imprime el resultado
# Out:
# [1, 'a', 2, 1, 'd']

# %% [markdown]
# <h2>Conclusiones</h2>
#
# Este cuaderno ayudo a comprender como crear listas con distintos tipos de datos incluidas otras listas o tuplas, junto con sus métodos y operaciones basicas, lo cual permite entender mejor la organización y distribución de los datos dentro de las listas.
